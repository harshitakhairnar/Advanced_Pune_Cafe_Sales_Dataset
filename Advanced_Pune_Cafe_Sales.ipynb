# %%
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df = pd.read_csv("C:\\Users\\Admin\\Documents\\Advanced_Pune_Cafe_Sales_2000.csv")

# %%
df.head()
# Out:
#    order_id        date outlet_location  outlet_manager customer_type  \
# 0  ORD51036  2025-10-19       Hinjewadi      Priya Nair       Regular
# 1  ORD94971  2025-10-09         Kothrud     Arjun Mehta       Tourist
# 2  ORD82709  2025-10-07     Viman Nagar  Rohit Deshmukh       Tourist
# 3  ORD61541  2025-10-22     Viman Nagar  Rohit Deshmukh       Tourist
# 4  ORD20674  2025-10-07         Kothrud     Arjun Mehta           New
#
#   item_category            item_name  quantity_sold  price_per_unit  \
# 0         Snack  Cheese Garlic Bread              4             245
# 1      Beverage           Cappuccino              3             134
# 2      Beverage            Green Tea              3             243
# 3      Beverage           Cappuccino              1             174
# 4       Dessert           Cheesecake              4             175
#
#    total_bill  cost_price  profit payment_mode time_of_day  temperature_c  \
# ...

# %%
df.tail()
# Out:
#       order_id        date outlet_location  outlet_manager customer_type  \
# 1995  ORD88057  2025-10-03     Viman Nagar  Rohit Deshmukh           New
# 1996  ORD71910  2025-10-26     Viman Nagar  Rohit Deshmukh       Tourist
# 1997  ORD13597  2025-10-14         Kothrud     Arjun Mehta       Tourist
# 1998  ORD37000  2025-10-18   Koregaon Park     Amit Sharma           New
# 1999  ORD86916  2025-10-22         Kothrud     Arjun Mehta           New
#
#      item_category      item_name  quantity_sold  price_per_unit  total_bill  \
# 1995      Beverage  Hot Chocolate              4             169         676
# 1996       Dessert        Brownie              1             171         171
# 1997         Snack          Pasta              4             162         648
# 1998         Snack   French Fries              3             234         702
# 1999      Beverage  Hot Chocolate              4             224         896
#
# ...

# %%
df.describe()
# Out:
#        quantity_sold  price_per_unit   total_bill   cost_price       profit  \
# count    2000.000000     2000.000000  2000.000000  2000.000000  2000.000000
# mean        2.499500      200.353000   500.813500   350.866920   149.946580
# std         1.113831       58.527866   274.319218   195.203022    88.624357
# min         1.000000      100.000000   100.000000    63.150000    21.620000
# 25%         2.000000      150.000000   267.750000   183.082500    79.637500
# 50%         3.000000      201.000000   460.000000   316.375000   131.355000
# 75%         3.000000      249.000000   696.750000   478.690000   203.172500
# max         4.000000      300.000000  1200.000000   946.730000   477.600000
#
#        temperature_c  customer_rating  discount_percent  final_amount  \
# count    2000.000000      2000.000000       2000.000000   2000.000000
# mean       29.518550         3.993100          7.642500    462.413100
# std         3.165595         0.581938          5.519957    255.380474
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 23 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   order_id                 2000 non-null   object
#  1   date                     2000 non-null   object
#  2   outlet_location          2000 non-null   object
#  3   outlet_manager           2000 non-null   object
#  4   customer_type            2000 non-null   object
#  5   item_category            2000 non-null   object
#  6   item_name                2000 non-null   object
#  7   quantity_sold            2000 non-null   int64
#  8   price_per_unit           2000 non-null   int64
#  9   total_bill               2000 non-null   int64
#  10  cost_price               2000 non-null   float64
#  11  profit                   2000 non-null   float64
#  12  payment_mode             2000 non-null   object
#  13  time_of_day              2000 non-null   object
# ...

# %%
df.describe(include = "all")
# Out:
#         order_id        date outlet_location outlet_manager customer_type  \
# count       2000        2000            2000           2000          2000
# unique      1979          31               5              5             3
# top     ORD89099  2025-10-19   Koregaon Park    Amit Sharma       Tourist
# freq           2          65             428            428           675
# mean         NaN         NaN             NaN            NaN           NaN
# std          NaN         NaN             NaN            NaN           NaN
# min          NaN         NaN             NaN            NaN           NaN
# 25%          NaN         NaN             NaN            NaN           NaN
# 50%          NaN         NaN             NaN            NaN           NaN
# 75%          NaN         NaN             NaN            NaN           NaN
# max          NaN         NaN             NaN            NaN           NaN
#
#        item_category  item_name  quantity_sold  price_per_unit   total_bill  \
# ...

# %%
df.describe(include=[object])
# Out:
#         order_id        date outlet_location outlet_manager customer_type  \
# count       2000        2000            2000           2000          2000
# unique      1979          31               5              5             3
# top     ORD89099  2025-10-19   Koregaon Park    Amit Sharma       Tourist
# freq           2          65             428            428           675
#
#        item_category  item_name payment_mode time_of_day day_of_week  \
# count           2000       2000         2000        2000        2000
# unique             3         17            3           4           7
# top         Beverage  Ice Cream         Card     Morning   Wednesday
# freq             696        145          683         524         324
#
#           special_event staff_id day_type
# count               593     2000     2000
# unique                3       30        2
# top     Weekend Special     ST22  Weekday
# freq                207       90     1483

# %%
df.describe()
# Out:
#        quantity_sold  price_per_unit   total_bill   cost_price       profit  \
# count    2000.000000     2000.000000  2000.000000  2000.000000  2000.000000
# mean        2.499500      200.353000   500.813500   350.866920   149.946580
# std         1.113831       58.527866   274.319218   195.203022    88.624357
# min         1.000000      100.000000   100.000000    63.150000    21.620000
# 25%         2.000000      150.000000   267.750000   183.082500    79.637500
# 50%         3.000000      201.000000   460.000000   316.375000   131.355000
# 75%         3.000000      249.000000   696.750000   478.690000   203.172500
# max         4.000000      300.000000  1200.000000   946.730000   477.600000
#
#        temperature_c  customer_rating  discount_percent  final_amount  \
# count    2000.000000      2000.000000       2000.000000   2000.000000
# mean       29.518550         3.993100          7.642500    462.413100
# std         3.165595         0.581938          5.519957    255.380474
# ...

# %% [markdown]
# **order_id -**
# - As the count in the **order_id feature is 2000** it has **no missing values.**
# - In this feature there are **1979 unique values**
# - **ORD67858** is the most **frequent title** which has been **repeated 2 times**.
#
# **date -**
# - As the count in the **date feature is 2000** it has **no missing values.**
# - In this feature there are **31 unique values.**
# - **2025-10-19** is the most **frequent date** which has been **repeated 65 times**.
#
# **outlet_location -**
# - As the count in the **date feature is 2000** it has **no missing values.**
# - In this feature there are **5 unique values.**
# - **Koregaon Park** is the most **frequent outlet_location** which has been **repeated 428 times**.
#
# **outlet_manager -**
# - As the count in the**outlet_manager feature is 2000** it has **no missing values.**
# - In this feature there are **5 unique values.**
# - **Amit Sharma** is the biggest **outlet_manager**.
#
# **customer_type -**
# - As the count in the**customer_type feature is 2000** it has **no missing values.**
# - In this feature there are **3 unique values.**
# - **Tourist** is the biggest **customer_type** which has **repeated 675 times**.
#
# **item_category -**
# - As the count in the**item_category feature is 2000** it has **no missing values.**
# - In this feature there are **5 unique values.**
# - **Beverage** is the biggest item_category which has been **repeated 696 times**.
#
# **item_name -**
# - As the count in the **item_name feature is 2000** it has **no missing values.**
# - In this feature there are **17 unique values.**
# - **Ice-Creame** is the most **frequent item_name** which has been **repeated 145 times**.
#
# **quantity_sold -**
# - As the count in the **quantity_sold feature is 2000** it has **no missing values.**
# - **mean is 2.4** and  **standard deviation is 1.4** in this observation we see the data is less Variated.
# - The **minimum value is 1.0**, and the **maximum is 4.0**.
# - In the feature **quantity_sold 25%** unit per transaction is **2.0.**
# - In the feature **quantity_sold 50%** unit per transaction is **3.0**.
# - In the feature **quantity_sold 75%** unit per transaction is **3.0**
#
# **price_per_unit -**
# - As the count in the **quantity_sold feature is 2000** it has **no missing values.**
# - **mean is 2.4** and  **standard deviation is 1.4** in this observation we see the data is less Variated.
# - The **minimum value is 1.0**, and the **maximum is 4.0**.
# - In the feature **quantity_sold 25%** unit per transaction is **2.0.**
# - In the feature **quantity_sold 50%** unit per transaction is **3.0**.
# - In the feature **quantity_sold 75%** unit per transaction is **3.0**
#
# **total_bill -**
# - As the count in the **total_bill feature is 2000** it has **no missing values.**
# - **mean is 2500.8** and  **standard deviation is 274.3** in this observation we see the data is less Variated.
# - The **minimum value is 100.0**, and the **maximum is 1200.0**.
# - In the feature **total_bill 25%** range is **267.7**
# - In the feature **total_bill 50%** range is **460.0**
# - In the feature **total_bill 75%** range is **496.0**
#
# **time_of_day -**
# - As the count in the **time_of_day feature is 2000** it has **no missing days.**
# - In this feature there are **2 unique days.**
# - This represents the time slot of each transaction **at the morning.**
#
# **temperature_c -**
# - As the count in the **temperature feature is 2000** it has **no missing values.**
# - **mean is 29.0** and  **standard deviation is 3.0** in this observation we see the data is more Variated.
# - The **minimum value is 24.0**, and the **maximum is 35.0**.
# - In the feature **temperature_c 25%** temp condition is **26.7**
# - In the feature **temperature_c 50%** temp condition is **29.6**
# - In the feature **temperature_c 75%** temp condition is **35.3**

# %%
df.isnull().sum()
# Out:
# order_id                      0
# date                          0
# outlet_location               0
# outlet_manager                0
# customer_type                 0
# item_category                 0
# item_name                     0
# quantity_sold                 0
# price_per_unit                0
# total_bill                    0
# cost_price                    0
# profit                        0
# payment_mode                  0
# time_of_day                   0
# temperature_c                 0
# day_of_week                   0
# customer_rating               0
# discount_percent              0
# final_amount                  0
# special_event              1407
# staff_id                      0
# day_type                      0
# cumulative_sales_outlet       0
# dtype: int64

# %%
df['special_event'].unique()
# Out:
# array(['Weekend Special', nan, 'Diwali Offer', 'Coffee Fest'],
#       dtype=object)

# %%
df['special_event'] = df['special_event'].fillna('Unknown')

# %%
df['special_event'].isnull().sum()
# Out:
# np.int64(0)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df['date'] = pd.to_datetime(df['date'])   # convert date dtype from object into datetime

# %%
df["year"]=df["date"].dt.year                # .dt.year extracts year from the mentioned date

# %%
df["month"] = df["date"].dt.month   # .dt.month extracts month from the mentioned date

# %%
df["Day"]=df["date"].dt.day                  # .dt.day extracts day from the mentioned date

# %%
df["month_name"] = df["date"].dt.month_name()

# %%
pd.set_option('display.max_columns', None)    #display all columns

# %%
df.head()
# Out:
#    order_id       date outlet_location  outlet_manager customer_type  \
# 0  ORD51036 2025-10-19       Hinjewadi      Priya Nair       Regular
# 1  ORD94971 2025-10-09         Kothrud     Arjun Mehta       Tourist
# 2  ORD82709 2025-10-07     Viman Nagar  Rohit Deshmukh       Tourist
# 3  ORD61541 2025-10-22     Viman Nagar  Rohit Deshmukh       Tourist
# 4  ORD20674 2025-10-07         Kothrud     Arjun Mehta           New
#
#   item_category            item_name  quantity_sold  price_per_unit  \
# 0         Snack  Cheese Garlic Bread              4             245
# 1      Beverage           Cappuccino              3             134
# 2      Beverage            Green Tea              3             243
# 3      Beverage           Cappuccino              1             174
# 4       Dessert           Cheesecake              4             175
#
#    total_bill  cost_price  profit payment_mode time_of_day  temperature_c  \
# ...

# %%
cat_col = ['outlet_location','outlet_manager','customer_type','item_category','item_name','payment_mode',
           'time_of_day','day_of_week','special_event','day_type','month_name']
for col in cat_col:
    value_counts = df[col].value_counts()
    print(f'{value_counts}\n')
# Out:
# outlet_location
# Koregaon Park    428
# Hinjewadi        405
# Viman Nagar      399
# Baner            389
# Kothrud          379
# Name: count, dtype: int64
#
# outlet_manager
# Amit Sharma       428
# Priya Nair        405
# Rohit Deshmukh    399
# Sneha Patil       389
# Arjun Mehta       379
# Name: count, dtype: int64
#
# customer_type
# Tourist    675
# Regular    674
# New        651
# Name: count, dtype: int64
#
# item_category
# Beverage    696
# Snack       665
# Dessert     639
# Name: count, dtype: int64
#
# item_name
# Ice Cream              145
# Iced Latte             145
# Brownie                140
# Cappuccino             131
# Hot Chocolate          129
# Paneer Wrap            124
# Chocolate Muffin       122
# Cold Coffee            120
# French Fries           120
# Donut                  117
# Cheesecake             115
# Burger                 114
# Cheese Garlic Bread    110
# Pasta                   99
# Veg Sandwich            98
# ...

# %%
df.shape
# Out:
# (2000, 27)

# %%
df.dtypes
# Out:
# order_id                           object
# date                       datetime64[ns]
# outlet_location                    object
# outlet_manager                     object
# customer_type                      object
# item_category                      object
# item_name                          object
# quantity_sold                       int64
# price_per_unit                      int64
# total_bill                          int64
# cost_price                        float64
# profit                            float64
# payment_mode                       object
# time_of_day                        object
# temperature_c                     float64
# day_of_week                        object
# customer_rating                   float64
# discount_percent                    int64
# final_amount                      float64
# special_event                      object
# staff_id                           object
# day_type                           object
# ...

# %%
plt.hist(df['final_amount'], color='skyblue', edgecolor='black')
plt.title('Final Amount Distribution')
plt.xlabel('Final Amount')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# - The graph is shows the Final Amount.
# - The highest Final Amount is between range 200 to 300, that have frequency 395.
# - The lowest Fianal Amount is between range 1100 to 1200, that have frequency 25.
# - This distribution is **Right-Skewed distribution** most values are low with fewer large values.

# %%
plt.hist(df['cumulative_sales_outlet'], color='skyblue', edgecolor='black')
plt.title('Cumulative Sales Outlet Distribution')
plt.xlabel('Cumulative Sales Outlet')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# - This graph is shows the histogram of Cumulative Sales Outlet.
# - The highest Cumulative Sales Outlet is 40000 to 80000 with frequency above 200.
# - The lowest Cumulative Sales Outlet is 170000 to 2000000 with frequency below 150.
# - This is the **uniform distribution**, many outlet perform similarly only few outlier on the high sales.

# %%
plt.hist(df['quantity_sold'], color='skyblue', edgecolor='black')
plt.title('Quantity sold Distribution')
plt.xlabel('Quantity Sold')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# - This graph is shows the histogram of quantity sold.
# - All items were sold in equal quantity.
# - There is no variation in quantity sold across transactions.
# - This is the **uniform distribution** the quantity sold is consistent across most ranges.

# %%
plt.hist(df['total_bill'], color='skyblue', edgecolor='black')
plt.title('Total Bill Distribution')
plt.xlabel('Total Bill')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# - This graph shows the histogram of total bill distribution.
# - The 200 to 300 customers have a total bill around 350.
# - The 1200 customers have very high bills around 50.
# - This is the **Right-Skewed Distribution** most bills falls between 200 to 600** and few bills are above 900 to 1200.

# %%
plt.hist(df['cost_price'], color='skyblue', edgecolor='black')
plt.title('Cost Price Distribution')
plt.xlabel('Cost Price')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# - The highest cost price is above 400 .
# - The lowest cost price is 10.
# - This is the **Right-Skewed Distribution** many low cost items few cost price.

# %%
plt.hist(df['profit'], color='skyblue', edgecolor='black')
plt.title('Profit Distribution')
plt.xlabel('Profit')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# - The higest transactions have a profit between 50 and 100, above 400 orders. .
# - The lowest transactions have a high profit between 450 and 500, only 50 orders.
# - This is the **Right-skewed Distribution**, many low profit , few high profits.

# %%
plt.hist(df['temperature_c'], color='skyblue', edgecolor='black')
plt.title('Temperature_C Distribution')
plt.xlabel('Temperature_C')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# - High temperature readings are around 30°C with a frequency above 200.
# - Low temprature readings are around 27°C with a frequency of about 170.
# - This is the **uniform distribution** temperature range is consistent across most temperature.

# %%
plt.hist(df['customer_rating'], color='skyblue', edgecolor='black')
plt.title('Customer Rating Distribution')
plt.xlabel('Customer Rating')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# - The highest customers gave high ratings between 4.75 and 5.00, with a frequency above 250.
# - The lowest customers gave low ratings between 3.00 and 3.25, with around 150.
# - This is the **Right-Skewed Distribution** , most customers have the highest frequency and **low customers have few rating.**

# %%
plt.hist(df['discount_percent'], color='skyblue', edgecolor='black')
plt.title('Discount Percent Distribution')
plt.xlabel('Discount Percent')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# - The highest discounts are between 4% and 6%, with a frequency above 500.
# - The lowest discounts fall between 0% and 2%, with a frequency above 400.
# - This is the **uniform distribution** discount percent frequency is consistent.

# %%
plt.hist(df['outlet_location'], bins=10, color='skyblue', edgecolor='black')
plt.title('Histogram ofoutlet_location')
plt.xlabel('outlet_location')
plt.ylabel('frequency')
plt.show()

# %% [markdown]
# - **This histogram shows tempereture of each location.**
# - The **lowest tempereture** is 370 degree in **kothrud location.**
# - The **highest tempereture** is above 400 degree in **koregoan park.**
# - This is the **unform distribution** , means this distribution is fairly even **all locations frequency are equal**.

# %%
plt.bar(df['outlet_location'],df['cumulative_sales_outlet'], color ="skyblue")
plt.title("Cumulative sales oulet by Outlet location")
plt.xlabel('outlet_location')
plt.ylabel('cumulative_sales_outlet')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# - **Kothrud and baner have cumulative sales around 175000.**
# - **Hinjewadi, Viman nagar and Koregaon Park have cumulative sales above 175000.**

# %%
plt.bar(df['day_type'],df['total_bill'], color ="skyblue")
plt.title("Total bill by day_type")
plt.xlabel('day_type')
plt.ylabel('total_bill')
plt.xticks(rotation=75)
plt.show()

# %% [markdown]
# - **Almost similar bill around Weekend and Weekday.**
# - **The total bill is near to 1200.**

# %%
plt.bar(df['day_type'],df['profit'], color ="skyblue")
plt.title("Profit by day_type")
plt.xlabel('day_type')
plt.ylabel('profit')
plt.show()

# %% [markdown]
# - **Highest profit is on Weekday around 500.**
# - **Very low profit is on Weekend around 450.**
# - **The visualization shows that the Profit is more on Weekday compare to Weekend.**

# %%
plt.boxplot(df['profit'])

plt.title('profit Box Plot')
plt.ylabel('profit')
plt.show()

# %% [markdown]
# - **The box plot summarizes how profit are distributed.**
# - **Most prices falls between 75 to 200 profit.**
# - **The median is around 140.**
# - There is outliers present in the upper whisker in **extreme high level.**

# %%
IQR = 203.172500 - 79.637500	
print(IQR)
lower_limit = 79.637500 - 1.5 * IQR
print(lower_limit)
upper_limit = 203.172500 + 1.5 * IQR
print(upper_limit)
# Out:
# 123.53500000000001
# -105.665
# 388.475

# %%
plt.boxplot(df['price_per_unit'])

plt.title('Price Per Unit Box Plot')
plt.ylabel('Price Per Unit')
plt.show()

# %% [markdown]
# - **The box plot summarizes how unit prices are distributed.**
# - **Most prices falls between 150 to 250 price per unit.**
# - **The median is around 200.**
# - **No outliers** found in this box plot.

# %%
IQR = 249.000000 - 150.000000	
print(IQR)
lower_limit = 150.000000 - 1.5 * IQR
print(lower_limit)
upper_limit = 249.000000 + 1.5 * IQR
print(upper_limit)
# Out:
# 99.0
# 1.5
# 397.5

# %%
plt.boxplot(df['total_bill'])

plt.title('total bill Box Plot')
plt.ylabel('total bill')
plt.show()

# %% [markdown]
# - **The box plot summarizes how total bill are distributed.**
# - **Most prices falls between 250 to 650 price per unit.**
# - **The median is around 410.**
# - There is **No outliers** present in this box plot.

# %%
IQR = 696.750000 - 267.750000	
print(IQR)
lower_limit = 267.750000 - 1.5 * IQR
print(lower_limit)
upper_limit = 696.750000 + 1.5 * IQR
print(upper_limit)
# Out:
# 429.0
# -375.75
# 1340.25

# %%
sns.countplot(x=df["outlet_location"], data=df)
plt.title("Count Plot for outlet_location")
plt.xticks(rotation = 45)
plt.show()

# %% [markdown]
# - **The visualization shows the count plot for outlet location.**
# - **The distribution shows the highest count of Koregaon park and its count around above 400.**
# - **The distribution shows the lowest count of Kothrud and its count around 375.**
# - **The distribution of Hinjewadi, Viman Nagar and Baner has count around 400.**

# %%
sns.countplot(x=df["customer_type"], data=df)
plt.title("Count Plot for customer_type")
plt.xticks(rotation = 45)
plt.show()

# %% [markdown]
# - **The visualization shows the count plot for Customer type.**
# - **The distribution shows the highest count of Regular and Tourist customer its count around above 680.**
# - **The distribution shows the lowest count of New customer and its count around 650.**

# %%
sns.countplot(x=df["item_category"], data=df)
plt.title("Count Plot for item_category")
plt.xticks(rotation = 45)
plt.show()

# %% [markdown]
# - **The visualization shows the count plot for Item category.**
# - **The distribution shows the highest count of Beverage and it has count around above 790.**
# - **The distribution shows the lowest count of Dessert and it has count around 620.**
# - **The distribution shows the medium count of Snack and it has count around 650.**

# %%
sns.countplot(x=df["payment_mode"], data=df)
plt.title("Count Plot for payment_mode")
plt.xticks(rotation = 45)
plt.show()

# %% [markdown]
# - **The visualization shows the count plot for Payment mode.**
# - **The distribution shows the highest count of Card payment mode and it has count around above 680.**
# - **The distribution shows the lowest count of Cash and UPI payment mode have count around 650.**

# %%
sns.countplot(x=df["day_of_week"], data=df)
plt.title("Count Plot for day_of_week")
plt.xticks(rotation = 45)
plt.show()

# %% [markdown]
# - **The visualization shows the count plot for Day of Week.**
# - **The distribution shows the highest count on Thursday, Wednesday and Friday and have count around above 300.**
# - **The distribution shows the lowest count on Sunday, Tuesday, Monday and Saturday have count around 250.**

# %%
# bivariate

sns.countplot(x=df["outlet_location"], hue="item_category", data = df)
plt.title("item_category wise outlet_location Split")
plt.xlabel("outlet_location")
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# - **The visualization indicates that the outlet location wise item category count.**
# - **In Hinjewadi has the highest count of Snack around 140 and lowest count in Viman Nagar around 130.**
# - **In Koregaon Park has the highest count of Beverage around 150 and lowest count in Kothrud around 125.**
# - **In Koregaon Park has the highest count of Dessert around 140 and lowest count in Kothrud around 115.**

# %%
sns.countplot(x=df["item_category"], hue="special_event", data = df)
plt.title("special_event wise item_category Split")
plt.xlabel("special_event")
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# - **The visualization indicates that the Special event wise item category count.**
# - **Snack, Beverage and Dessert items category have similar count on Weekend special events around 50.**
# - **Beverage items category has the highest count on Unknown event around 500 and Snack has lowest count around 450.**
# - **Snack and beverage item category has the highest count on Diwali offer around 50 and Dessert has the lowest count around 45.**
# - **Snack items has the highest count on Coffee fest around 100 and Dessert has the lowest count around 43.**

# %%
sns.countplot(x=df["payment_mode"], hue="day_type", data = df)
plt.title("day_type wise payment_mode Split")
plt.xlabel("payment_mode")
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# - **The Visualization indicates the Day type wise payment mode.**
# - **On the Weekend card payment mode has the highest count around 200 and UPI has the lowest count around 150.**
# - **On weekday all Cash, Card and UPI payment mode have similar count around 480.**

# %%
# Scatter Plot

plt.scatter(df["quantity_sold"], df["total_bill"])
plt.xlabel("quantity_sold")
plt.ylabel("total_bill")
plt.title("quantity_sold wise total_bill")
plt.show()

# %% [markdown]
# - **The visualization shows that the relationship between two features Quantity sold and total bill is Positive as the quantity sold increases the total bill also increases. There are few orders with 3 and 4 quantity with increases the total bill for these two quantities.**

# %%
plt.scatter(df["item_category"], df["total_bill"])
plt.xlabel("item_category")
plt.ylabel("total_bill")
plt.title("item_category wise total_bill")
plt.show()

# %% [markdown]
# - **The visualization indicates that the relationship between two features Item category and total bill there is no difference between the distribution. That means Snack, Beverage and Dessert all items category shows the similar patterns from range 200-1200.**

# %%
plt.scatter(df["cost_price"], df["profit"])
plt.xlabel("cost_price")
plt.ylabel("profit")
plt.title("cost_price wise profit")
plt.show()

# %% [markdown]
# - **The scatter plot shows the relation between Cost price and Profit.**
# - The graph indicates a **positive correlation** between these two variables, that means the Cost price increases the profit also increases.

# %%
plt.scatter(df['total_bill'],df['profit'])
plt.title("profit by total_bill")
plt.xlabel('total_bill')
plt.ylabel('profit')
plt.show()

# %% [markdown]
# - **The scatter plot shows the relation between total_bill and profit.**
# - The graph indicates a **positive correlation** between these two variables, that means the total_bill increases the profit also increases.

# %%
# BoxPlot
# Numerical VS Categorical 

sns.boxplot(x="customer_type", y="cost_price", data=df)
plt.title("customer type wise cost price")
plt.xlabel("customer type")
plt.ylabel("cost price")
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# - **The visualization indicates that the customers like Regualar, Tourist and New have similar median cost price. Also the Tourist has no outliers which indicates there is no such customers that increases the cost price.**

# %%
sns.boxplot(x="day_type", y="discount_percent", data=df)
plt.title("day_type wise discount_percent")
plt.xlabel("day_type")
plt.ylabel("discount_percent")
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# - **The visualization indicates that the Day type Weekday has higher median discount percentage,whereas Weedend has lower median discount percentage. Also the Weedend and Weekday have no outliers which indicates there is no such day that deriving the discount percentage to higher.**

# %%
sns.boxplot(x="time_of_day", y="profit", data=df)
plt.title("time_of_day wise profit")
plt.xlabel("time_of_day")
plt.ylabel("profit")
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# - **The visualization that indicates that the Time of day like Morning and Evening have the higher median profit, whereas the Afternoon and Night have the lower median profit. Also the Morning, Evening, Afternoon and Night have outliers.**

# %%
# Regreesion Plot
# Numerical Vs Numerical 

sns.regplot(x="quantity_sold", y="profit", data=df)
plt.title("Distribution of quantity_sold wise profit")
plt.xlabel("quantity_sold")
plt.ylabel("profit")
plt.show()

# %% [markdown]
# - **The visualization indicates an upward trend in quantity sold and Profit features, that means that there is Positive relationship as the Quantity sold increases the Profit also increases.**

# %%
sns.regplot(x="cost_price", y="discount_percent", data=df)
plt.title("Distribution of cost_price wise discount_percent")
plt.xlabel("cost_price")
plt.ylabel("discount_percent")
plt.show()

# %% [markdown]
# - **The visualization indicates that the regression line is flat there is no such trend in cost price and discount percentage,that means that there is no such relationship as cost price does not affect the discount percentage.**

# %%
sns.regplot(x="price_per_unit", y="discount_percent", data=df)
plt.title("Distribution of price_per_unit wise discount_percent")
plt.xlabel("price_per_unit")
plt.ylabel("discount_percent")
plt.show()

# %% [markdown]
# - **The visualization indicates that the regression line is flat there is no such trend in price per unit and discount percentage,that means that there is no such relationship as price per unit does not affect the discount percentage.**

# %%
# Sactter Plot
# Numerical Vs Numerical and hue=Categorical

sns.scatterplot(x="quantity_sold", y="total_bill", hue="payment_mode", data=df)
plt.title("Scatterplot for analyasing quantity sold and total bill with respect to Payment Mode")
plt.xlabel("quantity sold")
plt.ylabel("total bill")
plt.show()

# %% [markdown]
# - **The visualization shows the distribution of quantity sold and total bill with respect to payment mode.**
# - **For qunatity sold 1 Cash, Card and UPI equally spread for low bill amount.**
# - **For quantity sold 2 Card payment mode used higher for total bill amount.**
# - **For quantity sold 3 Cash payment mode highely used for high total bill.**
# - **For quantity sold 4 cash and Card similary used for total bill.**

# %%
sns.scatterplot(x="discount_percent", y="price_per_unit", hue="day_type", data=df)
plt.title("Scatterplot for analyasing price_per_unit sold and discount_percent with respect to day of week")
plt.xlabel("discount_percent")
plt.ylabel("price_per_unit")
plt.show()

# %% [markdown]
# - **The visualization shows the distribution of discount percent and price per unit with respect to Weekend-Weekday.**
# - **The price per unit on weekday has high has discount percent 0%, 5% and 14%.**
# - **The price per unit on weekend has highest discount percent that is 10% comparing to other days.**

# %%
# BoxPlot
# Categorical Vs Numerical and hue=Categorical

plt.figure(figsize=(15,8))
sns.boxplot(x="customer_type", y="customer_rating", hue="time_of_day", data=df)
plt.title("BoxPlot for analyasing customer_type and customer_rating with respect to time_of_day")
plt.xlabel("customer_type")
plt.ylabel("customer_rating")
plt.show()

# %% [markdown]
# - **The visualization indicates that for Regular customer median rating of Evening time is high and Afternoon is low,followed by Morning and Night.**
# - **For Tourist customer median rating of Morning time is high and Evening and Night time is low, followed by Afternoon.**
# - **For New customers median rating of Morining time is high and Evening time is low, followed by Afternoon and Night.**

# %%
plt.figure(figsize=(15,8))
sns.boxplot(x="time_of_day", y="total_bill", hue="day_type", data=df)
plt.title("BoxPlot for analyasing time_of_day and total_bill with respect to day_type")
plt.xlabel("time_of_day")
plt.ylabel("total_bill")
plt.show()

# %% [markdown]
# - **The visualization indicates that for Morning time median total bill of weekend day is highest and weekday has lowest.**
# - **For Evening time median total bill of weekend day is highest and weekday is lowest.**
# - **For Afternoon time median total bill of weekday is highest and weekend is lowest.**
# - **For Night time median total bill of weekend is highest and weekday is lowest.**

# %% [markdown]
# ## Cross tab for item category and customer type wise avg cost_price

# %%
#Cross Tab
 
ct1 = pd.crosstab(df["item_category"], df["customer_type"], values=df["cost_price"], aggfunc="mean")

# %%
ct1
# Out:
# customer_type         New     Regular     Tourist
# item_category
# Beverage       351.458197  351.733182  345.529959
# Dessert        337.567762  345.648789  358.332136
# Snack          351.074279  351.733203  364.778097

# %%
ct1.plot(kind="bar", figsize=(15,8))
plt.show()

# %% [markdown]
# - **The visualization indicates that for New customer type Beverage, Dessert and Snack category has highest avg cost price.**
# - **For Regular customer type Beverage, Dessert and Snack category has highest avg cost price.**
# - **For Tourist customer type Snack category has highest avg cost price and Beverage category has lowest avg cost price.**

# %%
plt.figure(figsize=(15,8))
sns.heatmap(ct1,annot=True, cmap='Blues')
plt.title("HeatMap using item_category and customer_type")
plt.xlabel("customer_type")
plt.ylabel("item_category")
plt.show()

# %% [markdown]
# - **The visualization indicates that the using heatmap data is distributed for item category and customer type features according to average cost price.**
# - **The heatmap indicates that the Tourist customer has positively correlated for the sales for Snack category.**
# - **The New customer has negatively correlated for sales for all items category.**
# - **The Regular customer show the balanced correlated for sales for all items category.**

# %%
ct2 = pd.crosstab(df["item_category"], df["payment_mode"], values=df["total_bill"], aggfunc="mean")

# %%
ct2
# Out:
# payment_mode         Card        Cash         UPI
# item_category
# Beverage       497.489362  506.788288  496.435146
# Dessert        444.434146  522.401826  503.037209
# Snack          549.045267  485.606481  493.131068

# %%
ct2.plot(kind="bar", figsize=(15,8))
plt.show()

# %% [markdown]
# - **The visualization indicates that for Beverage category Cash mode highely used and least used Card and UPI mode.**
# - **For Dessert category Cash mode highely used and least used UPI and Card.**
# - **For Snack category Card mode highely used and least used Cash and UPI.**

# %%
plt.figure(figsize=(15,8))
sns.heatmap(ct2,annot=True, cmap='Blues')
plt.title("HeatMap using item_category and payment_mode")
plt.xlabel("payment_mode")
plt.ylabel("item_category")
plt.show()

# %% [markdown]
# - **The visualization indicates that using heatmap data is distributed for item category and payment mode features according to average total bill.**
# - **The heatmap indicates that the Card mode has positively correlated for the bill for Snack category.**
# - **The Cash mode has balanced correlated for bill for all items category.**
# - **The UPI mode show the Negatively correlated for bill for all items category.**

# %%
final_amount_by_categories = df.groupby('item_category')['final_amount'].sum()

plt.pie(final_amount_by_categories, labels=final_amount_by_categories.index, autopct='%1.1f%%', startangle=90)

plt.title('Final Amount By Categories')
plt.axis('equal')
plt.show()

# %% [markdown]
# - **Beverage has the highest share at 34.9 %.**
# - **Snack follows closely with 33.7%, it shows the major sales category.**
# - **Dessert hast the lowest share at 31.4% but tghe different compared to other categories is small.**

# %%
profit_by_outlet_manager = df.groupby('outlet_manager')['profit'].sum()

plt.pie(profit_by_outlet_manager, labels=profit_by_outlet_manager.index, autopct='%1.1f%%', startangle=90)

plt.title('Profit By Outlet Manager')
plt.axis('equal')
plt.show()

# %% [markdown]
# - **This pie chart shows the sales share of each person.**
# - **Priya Nair has the highest share at 21%, followed closely by Amit Sharma 20.7% and Rohit Deshmukh 20.3%.**
# - **Sneha Patil has 19.1%, and Arjun Mehta has the lowest share at 18.8%.**
# - **All salespersons contributed almost equally with only a small difference in their percentages.**

# %%
data = ['profit','final_amount','total_bill','cost_price']
corr_data = df[data]
sns.heatmap(corr_data.corr(), annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# - **Profit and Cost price shows the positive correlation with value 0.85**
# - **Profit and Total bill shows the positive correlation with value 0.93**
# - **Profit and Final amount shows the positive correlation with value 0.92**
# - **Final amount and cost price shows the positive correlation with value 0.98**
# - **Final amount and Total bill shows the positive correlation with value 0.99**
# - **Total bill and cost price shows the postive correlation with value 0.99**
# - **The value 1.00 on the diagonal shows each feature is perfectly correlated with itself.**

# %%
plt.figure(figsize=(8, 5))    # Set figure size

sns.violinplot(data=df, x='outlet_location', y='total_bill', hue='outlet_location', palette="tab10", legend=False)    # Create violin plot

plt.title("Distribution of total_bill by outlet_location")     # Add title and labels
plt.xlabel("outlet_location")
plt.ylabel("total_bill")

plt.show()     # Show plot

# %% [markdown]
# - **The median bill value is almost the same across all outlet locations.**
# - **Hinjewadi and Koregaon Park show more high-spending customers, long tails means ourliers are present.**
# - **Baner and Kothrud have more same and middle range bills.**
# - **Viman nagar is balanced not too high and not too low.**

# %%
df1 = df.copy()

# %%
df.head()
# Out:
#    order_id       date outlet_location  outlet_manager customer_type  \
# 0  ORD51036 2025-10-19       Hinjewadi      Priya Nair       Regular
# 1  ORD94971 2025-10-09         Kothrud     Arjun Mehta       Tourist
# 2  ORD82709 2025-10-07     Viman Nagar  Rohit Deshmukh       Tourist
# 3  ORD61541 2025-10-22     Viman Nagar  Rohit Deshmukh       Tourist
# 4  ORD20674 2025-10-07         Kothrud     Arjun Mehta           New
#
#   item_category            item_name  quantity_sold  price_per_unit  \
# 0         Snack  Cheese Garlic Bread              4             245
# 1      Beverage           Cappuccino              3             134
# 2      Beverage            Green Tea              3             243
# 3      Beverage           Cappuccino              1             174
# 4       Dessert           Cheesecake              4             175
#
#    total_bill  cost_price  profit payment_mode time_of_day  temperature_c  \
# ...

# %%
df.describe(include=[object])
# Out:
#         order_id outlet_location outlet_manager customer_type item_category  \
# count       2000            2000           2000          2000          2000
# unique      1979               5              5             3             3
# top     ORD89099   Koregaon Park    Amit Sharma       Tourist      Beverage
# freq           2             428            428           675           696
#
#         item_name payment_mode time_of_day day_of_week special_event staff_id  \
# count        2000         2000        2000        2000          2000     2000
# unique         17            3           4           7             4       30
# top     Ice Cream         Card     Morning   Wednesday       Unknown     ST22
# freq          145          683         524         324          1407       90
#
#        day_type month_name
# count      2000       2000
# unique        2          1
# top     Weekday    October
# freq       1483       2000

# %%
# label encoding 

from sklearn.preprocessing import LabelEncoder
nominal_col = ["outlet_location","outlet_manager","customer_type","item_category","item_name","payment_mode",
               "time_of_day","day_of_week","special_event","day_type","month_name"]
encoder = LabelEncoder() # initializing label encoding
for col in nominal_col :
    df1[col] = encoder.fit_transform(df1[col])

# %%
df.head()
# Out:
#    order_id       date outlet_location  outlet_manager customer_type  \
# 0  ORD51036 2025-10-19       Hinjewadi      Priya Nair       Regular
# 1  ORD94971 2025-10-09         Kothrud     Arjun Mehta       Tourist
# 2  ORD82709 2025-10-07     Viman Nagar  Rohit Deshmukh       Tourist
# 3  ORD61541 2025-10-22     Viman Nagar  Rohit Deshmukh       Tourist
# 4  ORD20674 2025-10-07         Kothrud     Arjun Mehta           New
#
#   item_category            item_name  quantity_sold  price_per_unit  \
# 0         Snack  Cheese Garlic Bread              4             245
# 1      Beverage           Cappuccino              3             134
# 2      Beverage            Green Tea              3             243
# 3      Beverage           Cappuccino              1             174
# 4       Dessert           Cheesecake              4             175
#
#    total_bill  cost_price  profit payment_mode time_of_day  temperature_c  \
# ...
